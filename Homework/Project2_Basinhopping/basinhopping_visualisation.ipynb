# %%
from ase.visualize import view
from ase import Atoms
import numpy as np

# %%
"""
N=13 

Cluster Visualisation (Cambridge data)

"""

N=13
ground = np.array([1.0132226417, 0.3329955686, 0.1812866397,
                   0.7255989775, -0.7660449415, 0.2388625373, 
                   0.7293356067, -0.2309436666, -0.7649239428, 
                   0.3513618941, 0.8291166557, -0.5995702064, 
                   0.3453146118, -0.0366957540, 1.0245903005,
                   0.1140240770, 0.9491685999, 0.5064104273, 
                   -1.0132240213, -0.3329960305, -0.1812867552, 
                   -0.1140234764, -0.9491689127, -0.5064103454, 
                   -0.3513615244, -0.8291170821, 0.5995701458, 
                   -0.3453152548, 0.0366956843, -1.0245902691, 
                   -0.7255983925, 0.7660457628, -0.2388624662, 
                   -0.7293359733, 0.2309438428, 0.7649237858, 
                   0.0000008339, 0.0000002733, 0.0000001488])
cluster = Atoms('N'+str(N), positions=np.reshape(ground*2.0,[N,3]))
view(cluster)

# %%
"""
N=15

Cluster Visualisation (Cambridge data)

"""

N=15
ground = np.array([-0.2129011627, 1.1830393470, -0.9604753444, 
                   0.4813194372, 1.4576525309, -0.1048885461, 
                   -0.5524281203, -0.8820868881, 0.7313232547, 
                   0.3386980339, -1.2205295968, 0.1169633809,
                   -0.6370856835, -0.9454612228, -0.4032399496, 
                   0.4902092002, -0.4994913193, 0.9861954266, 
                   0.3526267627, -0.6187117318, -0.8460335492, 
                   -0.3944837472, 0.2069117580, 1.0121713817, 
                   -1.0933097468, -0.0695444859, 0.1508373136, 
                   1.0514536845, -0.3422412842, 0.0152913085, 
                   -0.5244447433, 0.1111651321, -0.8219255938, 
                   0.5919407629, 0.5528126270, 0.5540473173, 
                   -0.3984682119, 0.8092719413, 0.0635535286, 
                   0.5272515038, 0.4576793305, -0.5746954720,
                   -0.0203779694, -0.2004661379, 0.0808755433])
cluster = Atoms('N'+str(N), positions=np.reshape(ground*2.0,[N,3]))
view(cluster)

# %%
"""
N=17

Cluster Visualisation (Cambridge data)

"""

N=17
ground = np.array([-1.4927890568, 0.0801950784, -0.4804022863, 
                   0.3832871935, -0.2308985319, 1.5051295549, 
                   -1.2645827158, 0.2836524175, 0.6214942924,
                   -0.6590981862, -0.5449554650, 1.1552042113, 
                   0.6253588579, -0.2290468923, -1.1845756108, 
                   1.1789008612, 0.4741304013, -0.4818155915, 
                   0.1986774699, 0.7973208850, -0.9760036492, 
                   1.0927216037, -0.6219066728, -0.2167268299, 
                   0.0748361582, -0.9869157414, -0.5577188980, 
                   0.4123558404, 1.0530918138, 0.1077499046, 
                   -0.5000444130, -0.1017982275, -0.9994331852, 
                   0.9373386533, 0.1611949221, 0.5955520332, 
                   -0.6216625830, 0.6970177369, -0.2047505596, 
                   0.2605803622, -0.7460656159, 0.5382462185, 
                   -0.6917603796, -0.4522573646, 0.0518014568, 
                   -0.1642913474, 0.3359763080, 0.7388374053, 
                   0.2301716815, 0.0312649485, -0.2125884666])
cluster = Atoms('N'+str(N), positions=np.reshape(ground*2.0,[N,3]))
view(cluster)
